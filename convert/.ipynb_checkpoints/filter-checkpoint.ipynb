# %%
sys.path.append(os.path.join(os.path.dirname(os.getcwd())))
import sys, os
import nltk

# %%
from pymystem3 import Mystem

# %%
import trie.trie as trie

# %%
from stop_words import get_stop_words

# %%
trie.load_trie

# %%
CONJ= PART= APRO  SPRO SPRO ANUM= ADVPRO=

# %%
import goslate

# %%
gs = goslate.Goslate()

# %%
def

# %%
stemmer.analyze("Ксения чедесная однако")
# Out:
# [{'analysis': [{'gr': 'S,имя,жен,од=им,ед', 'lex': 'ксения'}],
#   'text': 'Ксения'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'A=им,ед,полн,жен',
#     'lex': 'чедесный',
#     'qual': 'bastard'}],
#   'text': 'чедесная'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'CONJ=', 'lex': 'однако'}], 'text': 'однако'},
#  {'text': '\n'}]

# %%
kek.

# %%
stemmer = Mystem()

# %%
 print(stemmer.analyze("по"))
# Out:
# [{'text': 'по', 'analysis': [{'lex': 'по', 'gr': 'PR='}]}, {'text': '\n'}]

# %%
class Filter():
    
    def __init__(self, path_to_stop_words_trie = None):
        self.stemmer_ = Mystem()
        #if path_to_stop_words_trie:
        #    self.stop_words_trie = trie.load_trie(path_to_stop_words_trie)
        #else:
        #    self.trie = trie.marisa_trie([])
    def get_word_from_token(self, token):
        print(token)
        
        if not "analysis" in token: #to be changed!
            return None
        
        if not token["analysis"]: #to be changed!
            return None
        
        if not "gr" in token["analysis"][0]: #to be changed!
            return None
        
        
        if token["analysis"][0]["gr"] in filtered_parts:
            return None

        if token["analysis"][0]["gr"].startswith("ADV,прдк="):
            return None
        
        if token["analysis"][0]["gr"].startswith("SPRO"): 
            return None
        
        if token["analysis"][0]["gr"].startswith("APRO"): 
            return None
        
        if 'фам,жен' in token["analysis"][0]["gr"]:
            return "фамиия_жен"

        if 'имя,жен' in token["analysis"][0]["gr"]:
            return "имя_жен"

        if 'фам,муж' in token["analysis"][0]["gr"]:
            return "фамиия_муж"

        if 'имя,муж' in token["analysis"][0]["gr"]:
            return "имя_муж"

        if 'фам,муж' in token["analysis"][0]["gr"]:
            return "имя_муж"

        return token["analysis"][0]["lex"]
    
    def get_tokens(self, text):
        return [lex for lex in  
                  [self.get_word_from_token(word) for word in self.stemmer_.analyze(text)] if None != lex ]
    
    filtered_parts = { 
        'CONJ=', "PART=", "APRO=", "SPRO=", 
        "SPRO=", "ANUM=", "ADVPRO=", "PR=", "ADV,прдк=", 'ADV,срвн='}

# %%
filtered_parts = { 
        'CONJ=', "PART=", "APRO=", "SPRO=", 
        "SPRO=", "ANUM=", "ADVPRO=", "PR=", "ADV,прдк=", 'ADV=срав'}

# %%
print(get_word_from_token(stemmer.analyze("её")[0]))
# Out:
# {'text': 'её', 'analysis': [{'lex': 'она', 'gr': 'SPRO,ед,3-л,жен=(вин|род)'}]}
# None

# %%
text = '''вой первБьорк (Бьёрк) Гудмундсдоттир (исл. Björk Guðmundsdóttir, [ˈpjœr̥k ˈkvʏðmʏntsˌtoʊhtɪr]; 21 ноября 1965, Рейкьявик, Исландия) — исландская певица, актриса, музыкант, композитор и автор песен, лауреат множества премий.
ице. Именно под влиянием этого инцидента Бьорк записала и выпустила в 1997 году поворотный в её творчестве альбом — «Homogenic»[21][22].ый альбом записала в 11 лет, он приобрёл большую популярность в Исландии, но мировую известность Бьорк получила как вокалистка альтернативной рок-группы «The Sugarcubes», чей сингл «Birthday» в 1987 году стал хитом в Великобритании и США, а также полюбился музыкальным критикам. Сольную карьеру Бьорк начала в 1993 году, её альбом «Debut» имел в основе электронную танцевальную музыку, хаус, джаз и трип-хоп. По общему признанию, это один из первых альбомов по внедрению альтернативной электронной музыки в мейнстрим. Было продано более 4,7 млн копий «Debut» по всему миру.'''

# %%
filter = Filter()

# %%
print(filter.get_tokens(text))
# Out:
# {'text': 'вой', 'analysis': [{'lex': 'вой', 'gr': 'S,муж,неод=(вин,ед|им,ед)'}]}
# {'text': ' '}
# {'text': 'первБьорк', 'analysis': [{'lex': 'первбьорк', 'qual': 'bastard', 'gr': 'S,муж,неод=(вин,ед|им,ед)'}]}
# {'text': ' ('}
# {'text': 'Бьёрк', 'analysis': [{'lex': 'бьерк', 'qual': 'bastard', 'gr': 'S,фам,муж,од=им,ед'}]}
# {'text': ') '}
# {'text': 'Гудмундсдоттир', 'analysis': [{'lex': 'гудмундсдоттир', 'qual': 'bastard', 'gr': 'S,муж,од=им,ед'}]}
# {'text': ' ('}
# {'text': 'исл', 'analysis': [{'lex': 'исла', 'gr': 'S,имя,жен,од=(вин,мн|род,мн)'}]}
# {'text': '. '}
# {'text': 'Björk', 'analysis': []}
# {'text': ' '}
# {'text': 'Guðmundsdóttir', 'analysis': []}
# {'text': ', ['}
# {'text': 'ˈpjœr̥k', 'analysis': []}
# {'text': ' '}
# {'text': 'ˈkvʏðmʏntsˌtoʊhtɪr', 'analysis': []}
# {'text': ']; '}
# {'text': '21'}
# {'text': ' '}
# {'text': 'ноября', 'analysis': [{'lex': 'ноябрь', 'gr': 'S,муж,неод=род,ед'}]}
# {'text': ' '}
# {'text': '1965'}
# {'text': ', '}
# {'text': 'Рейкьявик', 'analysis': [{'lex': 'рейкьявик', 'gr': 'S,гео,муж,неод=(вин,ед|им,ед)'}]}
# {'text': ', '}
# {'text': 'Исландия', 'analysis': [{'lex': 'исландия', 'gr': 'S,гео,жен,неод=им,ед'}]}
# {'text': ') — '}
# {'text': 'исландская', 'analysis': [{'lex': 'исландский', 'gr': 'A=им,ед,полн,жен'}]}
# {'text': ' '}
# {'text': 'певица', 'analysis': [{'lex': 'певица', 'gr': 'S,жен,од=им,ед'}]}
# {'text': ', '}
# {'text': 'актриса', 'analysis': [{'lex': 'актриса', 'gr': 'S,жен,од=им,ед'}]}
# {'text': ', '}
# {'text': 'музыкант', 'analysis': [{'lex': 'музыкант', 'gr': 'S,муж,од=им,ед'}]}
# {'text': ', '}
# {'text': 'композитор', 'analysis': [{'lex': 'композитор', 'gr': 'S,муж,од=им,ед'}]}
# {'text': ' '}
# {'text': 'и', 'analysis': [{'lex': 'и', 'gr': 'CONJ='}]}
# {'text': ' '}
# {'text': 'автор', 'analysis': [{'lex': 'автор', 'gr': 'S,муж,од=им,ед'}]}
# {'text': ' '}
# {'text': 'песен', 'analysis': [{'lex': 'песня', 'gr': 'S,жен,неод=род,мн'}]}
# {'text': ', '}
# {'text': 'лауреат', 'analysis': [{'lex': 'лауреат', 'gr': 'S,муж,од=им,ед'}]}
# {'text': ' '}
# {'text': 'множества', 'analysis': [{'lex': 'множество', 'gr': 'S,сред,неод=(вин,мн|род,ед|им,мн)'}]}
# {'text': ' '}
# {'text': 'премий', 'analysis': [{'lex': 'премия', 'gr': 'S,жен,неод=род,мн'}]}
# {'text': '.'}
# {'text': '\n'}
# {'text': 'Свой', 'analysis': [{'lex': 'свой', 'gr': 'APRO=(вин,ед,муж,неод|им,ед,муж)'}]}
# {'text': ' '}
# {'text': 'первый', 'analysis': [{'lex': 'первый', 'gr': 'ANUM=(вин,ед,муж,неод|им,ед,муж)'}]}
# {'text': ' '}
# {'text': 'альбом', 'analysis': [{'lex': 'альбом', 'gr': 'S,муж,неод=(вин,ед|им,ед)'}]}
# {'text': ' '}
# {'text': 'записала', 'analysis': [{'lex': 'записывать', 'gr': 'V,пе=прош,ед,изъяв,жен,сов'}]}
# {'text': ' '}
# {'text': 'в', 'analysis': [{'lex': 'в', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': '11'}
# {'text': ' '}
# {'text': 'лет', 'analysis': [{'lex': 'год', 'gr': 'S,муж,неод=род,мн'}]}
# {'text': ', '}
# {'text': 'он', 'analysis': [{'lex': 'он', 'gr': 'SPRO,ед,3-л,муж=им'}]}
# {'text': ' '}
# {'text': 'приобрёл', 'analysis': [{'lex': 'приобретать', 'gr': 'V=прош,ед,изъяв,муж,сов'}]}
# {'text': ' '}
# {'text': 'большую', 'analysis': [{'lex': 'большой', 'gr': 'A=вин,ед,полн,жен'}]}
# {'text': ' '}
# {'text': 'популярность', 'analysis': [{'lex': 'популярность', 'gr': 'S,жен,неод=(вин,ед|им,ед)'}]}
# {'text': ' '}
# {'text': 'в', 'analysis': [{'lex': 'в', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'Исландии', 'analysis': [{'lex': 'исландия', 'gr': 'S,гео,жен,неод=(пр,ед|вин,мн|дат,ед|род,ед|им,мн)'}]}
# {'text': ', '}
# {'text': 'но', 'analysis': [{'lex': 'но', 'gr': 'CONJ='}]}
# {'text': ' '}
# {'text': 'мировую', 'analysis': [{'lex': 'мировой', 'gr': 'A=вин,ед,полн,жен'}]}
# {'text': ' '}
# {'text': 'известность', 'analysis': [{'lex': 'известность', 'gr': 'S,жен,неод=(вин,ед|им,ед)'}]}
# {'text': ' '}
# {'text': 'Бьорк', 'analysis': [{'lex': 'бьорк', 'qual': 'bastard', 'gr': 'S,муж,од=им,ед'}]}
# {'text': ' '}
# {'text': 'получила', 'analysis': [{'lex': 'получать', 'gr': 'V,пе=прош,ед,изъяв,жен,сов'}]}
# {'text': ' '}
# {'text': 'как', 'analysis': [{'lex': 'как', 'gr': 'CONJ='}]}
# {'text': ' '}
# {'text': 'вокалистка', 'analysis': [{'lex': 'вокалистка', 'gr': 'S,жен,од=им,ед'}]}
# {'text': ' '}
# {'text': 'альтернативной', 'analysis': [{'lex': 'альтернативный', 'gr': 'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)'}]}
# {'text': ' '}
# {'text': 'рок-группы', 'analysis': [{'lex': 'рок-группа', 'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}]}
# {'text': ' «'}
# {'text': 'The', 'analysis': []}
# {'text': ' '}
# {'text': 'Sugarcubes', 'analysis': []}
# {'text': '», '}
# {'text': 'чей', 'analysis': [{'lex': 'чей', 'gr': 'APRO=(вин,ед,муж,неод|им,ед,муж)'}]}
# {'text': ' '}
# {'text': 'сингл', 'analysis': [{'lex': 'сингл', 'gr': 'S,муж,неод=(вин,ед|им,ед)'}]}
# {'text': ' «'}
# {'text': 'Birthday', 'analysis': []}
# {'text': '» '}
# {'text': 'в', 'analysis': [{'lex': 'в', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': '1987'}
# {'text': ' '}
# {'text': 'году', 'analysis': [{'lex': 'год', 'gr': 'S,муж,неод=(дат,ед|местн,ед)'}]}
# {'text': ' '}
# {'text': 'стал', 'analysis': [{'lex': 'становиться', 'gr': 'V,нп=прош,ед,изъяв,муж,сов'}]}
# {'text': ' '}
# {'text': 'хитом', 'analysis': [{'lex': 'хит', 'gr': 'S,муж,неод=твор,ед'}]}
# {'text': ' '}
# {'text': 'в', 'analysis': [{'lex': 'в', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'Великобритании', 'analysis': [{'lex': 'великобритания', 'gr': 'S,гео,жен,неод=(пр,ед|вин,мн|дат,ед|род,ед|им,мн)'}]}
# {'text': ' '}
# {'text': 'и', 'analysis': [{'lex': 'и', 'gr': 'CONJ='}]}
# {'text': ' '}
# {'text': 'США', 'analysis': [{'lex': 'сша', 'gr': 'S,сокр,гео,мн,неод=(пр|вин|дат|род|твор|им)'}]}
# {'text': ', '}
# {'text': 'а', 'analysis': [{'lex': 'а', 'gr': 'CONJ='}]}
# {'text': ' '}
# {'text': 'также', 'analysis': [{'lex': 'также', 'gr': 'ADV='}]}
# {'text': ' '}
# {'text': 'полюбился', 'analysis': [{'lex': 'полюбиться', 'gr': 'V,сов,нп=прош,ед,изъяв,муж'}]}
# {'text': ' '}
# {'text': 'музыкальным', 'analysis': [{'lex': 'музыкальный', 'gr': 'A=(дат,мн,полн|твор,ед,полн,муж|твор,ед,полн,сред)'}]}
# {'text': ' '}
# {'text': 'критикам', 'analysis': [{'lex': 'критик', 'gr': 'S,муж,од=дат,мн'}]}
# {'text': '. '}
# {'text': 'Сольную', 'analysis': [{'lex': 'сольный', 'gr': 'A=вин,ед,полн,жен'}]}
# {'text': ' '}
# {'text': 'карьеру', 'analysis': [{'lex': 'карьера', 'gr': 'S,жен,неод=вин,ед'}]}
# {'text': ' '}
# {'text': 'Бьорк', 'analysis': [{'lex': 'бьорк', 'qual': 'bastard', 'gr': 'S,муж,од=им,ед'}]}
# {'text': ' '}
# {'text': 'начала', 'analysis': [{'lex': 'начало', 'gr': 'S,сред,неод=(вин,мн|род,ед|им,мн)'}]}
# {'text': ' '}
# {'text': 'в', 'analysis': [{'lex': 'в', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': '1993'}
# {'text': ' '}
# {'text': 'году', 'analysis': [{'lex': 'год', 'gr': 'S,муж,неод=(дат,ед|местн,ед)'}]}
# {'text': ', '}
# {'text': 'её', 'analysis': [{'lex': 'ее', 'gr': 'APRO=(пр,мн|дат,мн|род,мн|твор,мн|им,мн|им,ед,жен|вин,ед,муж,од|род,ед,муж|род,ед,сред|вин,ед,сред|им,ед,сред|пр,ед,жен|дат,ед,жен|род,ед,жен|твор,ед,жен|пр,ед,муж|пр,ед,сред|дат,ед,муж|дат,ед,сред|вин,ед,жен|вин,мн,неод|вин,ед,муж,неод|им,ед,муж|твор,ед,муж|твор,ед,сред|вин,мн,од|пр,мн,сред|вин,мн,сред|дат,мн,сред|род,мн,сред|твор,мн,сред|им,мн,сред|пр,мн,муж|вин,мн,муж|вин,ед,муж|дат,мн,муж)'}]}
# {'text': ' '}
# {'text': 'альбом', 'analysis': [{'lex': 'альбом', 'gr': 'S,муж,неод=(вин,ед|им,ед)'}]}
# {'text': ' «'}
# {'text': 'Debut', 'analysis': []}
# {'text': '» '}
# {'text': 'имел', 'analysis': [{'lex': 'иметь', 'gr': 'V,несов,пе=прош,ед,изъяв,муж'}]}
# {'text': ' '}
# {'text': 'в', 'analysis': [{'lex': 'в', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'основе', 'analysis': [{'lex': 'основа', 'gr': 'S,жен,неод=(пр,ед|дат,ед)'}]}
# {'text': ' '}
# {'text': 'электронную', 'analysis': [{'lex': 'электронный', 'gr': 'A=вин,ед,полн,жен'}]}
# {'text': ' '}
# {'text': 'танцевальную', 'analysis': [{'lex': 'танцевальный', 'gr': 'A=вин,ед,полн,жен'}]}
# {'text': ' '}
# {'text': 'музыку', 'analysis': [{'lex': 'музыка', 'gr': 'S,жен,неод=вин,ед'}]}
# {'text': ', '}
# {'text': 'хаус', 'analysis': [{'lex': 'хаус', 'gr': 'S,муж,неод=(вин,ед|им,ед)'}]}
# {'text': ', '}
# {'text': 'джаз', 'analysis': [{'lex': 'джаз', 'gr': 'S,муж,неод=(вин,ед|им,ед)'}]}
# {'text': ' '}
# {'text': 'и', 'analysis': [{'lex': 'и', 'gr': 'CONJ='}]}
# {'text': ' '}
# {'text': 'трип', 'analysis': [{'lex': 'трип', 'gr': 'S,муж,неод=(вин,ед|им,ед)'}]}
# {'text': '-'}
# {'text': 'хоп', 'analysis': [{'lex': 'хоп', 'gr': 'INTJ='}]}
# {'text': '. '}
# {'text': 'По', 'analysis': [{'lex': 'по', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'общему', 'analysis': [{'lex': 'общий', 'gr': 'A=(дат,ед,полн,муж|дат,ед,полн,сред)'}]}
# {'text': ' '}
# {'text': 'признанию', 'analysis': [{'lex': 'признание', 'gr': 'S,сред,неод=дат,ед'}]}
# {'text': ', '}
# {'text': 'это', 'analysis': [{'lex': 'это', 'gr': 'PART='}]}
# {'text': ' '}
# {'text': 'один', 'analysis': [{'lex': 'один', 'gr': 'APRO=(вин,ед,муж,неод|им,ед,муж)'}]}
# {'text': ' '}
# {'text': 'из', 'analysis': [{'lex': 'из', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'первых', 'analysis': [{'lex': 'первый', 'gr': 'ANUM=(пр,мн|род,мн|вин,мн,од)'}]}
# {'text': ' '}
# {'text': 'альбомов', 'analysis': [{'lex': 'альбом', 'gr': 'S,муж,неод=род,мн'}]}
# {'text': ' '}
# {'text': 'по', 'analysis': [{'lex': 'по', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'внедрению', 'analysis': [{'lex': 'внедрение', 'gr': 'S,сред,неод=дат,ед'}]}
# {'text': ' '}
# {'text': 'альтернативной', 'analysis': [{'lex': 'альтернативный', 'gr': 'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)'}]}
# {'text': ' '}
# {'text': 'электронной', 'analysis': [{'lex': 'электронный', 'gr': 'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)'}]}
# {'text': ' '}
# {'text': 'музыки', 'analysis': [{'lex': 'музыка', 'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}]}
# {'text': ' '}
# {'text': 'в', 'analysis': [{'lex': 'в', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'мейнстрим', 'analysis': [{'lex': 'мейнстрим', 'gr': 'S,муж,неод=(вин,ед|им,ед)'}]}
# {'text': '. '}
# {'text': 'Было', 'analysis': [{'lex': 'быть', 'gr': 'V,нп=прош,ед,изъяв,сред,несов'}]}
# {'text': ' '}
# {'text': 'продано', 'analysis': [{'lex': 'продавать', 'gr': 'V,пе=прош,ед,прич,кр,сред,сов,страд'}]}
# {'text': ' '}
# {'text': 'более', 'analysis': [{'lex': 'много', 'gr': 'ADV=срав'}]}
# {'text': ' '}
# {'text': '4'}
# {'text': ','}
# {'text': '7'}
# {'text': ' '}
# {'text': 'млн', 'analysis': []}
# {'text': ' '}
# {'text': 'копий', 'analysis': [{'lex': 'копия', 'gr': 'S,жен,неод=род,мн'}]}
# {'text': ' «'}
# {'text': 'Debut', 'analysis': []}
# {'text': '» '}
# {'text': 'по', 'analysis': [{'lex': 'по', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'всему', 'analysis': [{'lex': 'весь', 'gr': 'APRO=(дат,ед,муж|дат,ед,сред)'}]}
# {'text': ' '}
# {'text': 'миру', 'analysis': [{'lex': 'мир', 'gr': 'S,муж,неод=дат,ед'}]}
# {'text': '.'}
# {'text': '\n'}
# {'text': 'На', 'analysis': [{'lex': 'на', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'настоящий', 'analysis': [{'lex': 'настоящий', 'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)'}]}
# {'text': ' '}
# {'text': 'момент', 'analysis': [{'lex': 'момент', 'gr': 'S,муж,неод=(вин,ед|им,ед)'}]}
# {'text': ' '}
# {'text': 'Бьорк', 'analysis': [{'lex': 'бьорк', 'qual': 'bastard', 'gr': 'S,муж,од=им,ед'}]}
# {'text': ' '}
# {'text': 'разработала', 'analysis': [{'lex': 'разрабатывать', 'gr': 'V,пе=прош,ед,изъяв,жен,сов'}]}
# {'text': ' '}
# {'text': 'свой', 'analysis': [{'lex': 'свой', 'gr': 'APRO=(вин,ед,муж,неод|им,ед,муж)'}]}
# {'text': ' '}
# {'text': 'собственный', 'analysis': [{'lex': 'собственный', 'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)'}]}
# {'text': ' '}
# {'text': 'эклектичный', 'analysis': [{'lex': 'эклектичный', 'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)'}]}
# {'text': ' '}
# {'text': 'музыкальный', 'analysis': [{'lex': 'музыкальный', 'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)'}]}
# {'text': ' '}
# {'text': 'стиль', 'analysis': [{'lex': 'стиль', 'gr': 'S,муж,неод=(вин,ед|им,ед)'}]}
# {'text': ', '}
# {'text': 'который', 'analysis': [{'lex': 'который', 'gr': 'APRO=(вин,ед,муж,неод|им,ед,муж)'}]}
# {'text': ' '}
# {'text': 'включает', 'analysis': [{'lex': 'включать', 'gr': 'V,пе=непрош,ед,изъяв,3-л,несов'}]}
# {'text': ' '}
# {'text': 'в', 'analysis': [{'lex': 'в', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'себя', 'analysis': [{'lex': 'себя', 'gr': 'SPRO=(вин|род)'}]}
# {'text': ' '}
# {'text': 'аспекты', 'analysis': [{'lex': 'аспект', 'gr': 'S,муж,неод=(вин,мн|им,мн)'}]}
# {'text': ' '}
# {'text': 'электроники', 'analysis': [{'lex': 'электроника', 'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}]}
# {'text': ', '}
# {'text': 'классики', 'analysis': [{'lex': 'классика', 'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}]}
# {'text': ', '}
# {'text': 'авангардной', 'analysis': [{'lex': 'авангардный', 'gr': 'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)'}]}
# {'text': ' '}
# {'text': 'музыки', 'analysis': [{'lex': 'музыка', 'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}]}
# {'text': ', '}
# {'text': 'альтернативной', 'analysis': [{'lex': 'альтернативный', 'gr': 'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)'}]}
# {'text': ' '}
# {'text': 'танцевальной', 'analysis': [{'lex': 'танцевальный', 'gr': 'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)'}]}
# {'text': ' '}
# {'text': 'музыки', 'analysis': [{'lex': 'музыка', 'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}]}
# {'text': ', '}
# {'text': 'рока', 'analysis': [{'lex': 'рок', 'gr': 'S,муж,неод=род,ед'}]}
# {'text': ' '}
# {'text': 'и', 'analysis': [{'lex': 'и', 'gr': 'CONJ='}]}
# {'text': ' '}
# {'text': 'джаза', 'analysis': [{'lex': 'джаз', 'gr': 'S,муж,неод=род,ед'}]}
# {'text': '. '}
# {'text': 'Бьорк', 'analysis': [{'lex': 'бьорк', 'qual': 'bastard', 'gr': 'S,муж,од=им,ед'}]}
# {'text': ' '}
# {'text': 'написала', 'analysis': [{'lex': 'написать', 'gr': 'V,сов,пе=прош,ед,изъяв,жен'}]}
# {'text': ' '}
# {'text': 'музыку', 'analysis': [{'lex': 'музыка', 'gr': 'S,жен,неод=вин,ед'}]}
# {'text': ' '}
# {'text': 'к', 'analysis': [{'lex': 'к', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'фильму', 'analysis': [{'lex': 'фильм', 'gr': 'S,муж,неод=дат,ед'}]}
# {'text': ' «'}
# {'text': 'Танцующая', 'analysis': [{'lex': 'танцующий', 'gr': 'A=им,ед,полн,жен'}]}
# {'text': ' '}
# {'text': 'в', 'analysis': [{'lex': 'в', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'темноте', 'analysis': [{'lex': 'темнота', 'gr': 'S,ед,жен,неод=(пр|дат)'}]}
# {'text': '» '}
# {'text': 'Ларса', 'analysis': [{'lex': 'ларс', 'gr': 'S,имя,муж,од=(вин,ед|род,ед)'}]}
# {'text': ' '}
# {'text': 'фон', 'analysis': [{'lex': 'фон', 'gr': 'S,муж,неод=(вин,ед|им,ед)'}]}
# {'text': ' '}
# {'text': 'Триера', 'analysis': [{'lex': 'триер', 'gr': 'S,фам,муж,од=(вин,ед|род,ед)'}]}
# {'text': ', '}
# {'text': 'в', 'analysis': [{'lex': 'в', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'котором', 'analysis': [{'lex': 'который', 'gr': 'APRO=(пр,ед,муж|пр,ед,сред)'}]}
# {'text': ' '}
# {'text': 'сыграла', 'analysis': [{'lex': 'сыграть', 'gr': 'V,сов,пе=прош,ед,изъяв,жен'}]}
# {'text': ' '}
# {'text': 'главную', 'analysis': [{'lex': 'главный', 'gr': 'A=вин,ед,полн,жен'}]}
# {'text': ' '}
# {'text': 'роль', 'analysis': [{'lex': 'роль', 'gr': 'S,жен,неод=(вин,ед|им,ед)'}]}
# {'text': ' '}
# {'text': 'и', 'analysis': [{'lex': 'и', 'gr': 'CONJ='}]}
# {'text': ' '}
# {'text': 'получила', 'analysis': [{'lex': 'получать', 'gr': 'V,пе=прош,ед,изъяв,жен,сов'}]}
# {'text': ' '}
# {'text': 'приз', 'analysis': [{'lex': 'приз', 'gr': 'S,муж,неод=(вин,ед|им,ед)'}]}
# {'text': ' '}
# {'text': 'как', 'analysis': [{'lex': 'как', 'gr': 'CONJ='}]}
# {'text': ' '}
# {'text': 'лучшая', 'analysis': [{'lex': 'хороший', 'gr': 'A=им,ед,полн,прев,жен'}]}
# {'text': ' '}
# {'text': 'актриса', 'analysis': [{'lex': 'актриса', 'gr': 'S,жен,од=им,ед'}]}
# {'text': ' '}
# {'text': 'на', 'analysis': [{'lex': 'на', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'Каннском', 'analysis': [{'lex': 'каннский', 'qual': 'bastard', 'gr': 'A=(пр,ед,полн,муж|пр,ед,полн,сред)'}]}
# {'text': ' '}
# {'text': 'кинофестивале', 'analysis': [{'lex': 'кинофестиваль', 'gr': 'S,муж,неод=пр,ед'}]}
# {'text': '. '}
# {'text': 'Также', 'analysis': [{'lex': 'также', 'gr': 'ADV='}]}
# {'text': ' '}
# {'text': 'она', 'analysis': [{'lex': 'она', 'gr': 'SPRO,ед,3-л,жен=им'}]}
# {'text': ' '}
# {'text': 'приняла', 'analysis': [{'lex': 'принимать', 'gr': 'V=прош,ед,изъяв,жен,сов'}]}
# {'text': ' '}
# {'text': 'участие', 'analysis': [{'lex': 'участие', 'gr': 'S,сред,неод=(вин,ед|им,ед)'}]}
# {'text': ' '}
# {'text': 'в', 'analysis': [{'lex': 'в', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'качестве', 'analysis': [{'lex': 'качество', 'gr': 'S,сред,неод=пр,ед'}]}
# {'text': ' '}
# {'text': 'композитора', 'analysis': [{'lex': 'композитор', 'gr': 'S,муж,од=(вин,ед|род,ед)'}]}
# {'text': ' '}
# {'text': 'и', 'analysis': [{'lex': 'и', 'gr': 'CONJ='}]}
# {'text': ' '}
# {'text': 'актрисы', 'analysis': [{'lex': 'актриса', 'gr': 'S,жен,од=(род,ед|им,мн)'}]}
# {'text': ' '}
# {'text': 'в', 'analysis': [{'lex': 'в', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'фильме', 'analysis': [{'lex': 'фильм', 'gr': 'S,муж,неод=пр,ед'}]}
# {'text': ' «'}
# {'text': 'Drawing', 'analysis': []}
# {'text': ' '}
# {'text': 'Restraint', 'analysis': []}
# {'text': ' '}
# {'text': '9'}
# {'text': '» '}
# {'text': 'своего', 'analysis': [{'lex': 'свой', 'gr': 'APRO=(вин,ед,муж,од|род,ед,муж|род,ед,сред)'}]}
# {'text': ' '}
# {'text': 'тогдашнего', 'analysis': [{'lex': 'тогдашний', 'gr': 'A=(вин,ед,полн,муж,од|род,ед,полн,муж|род,ед,полн,сред)'}]}
# {'text': ' '}
# {'text': 'мужа', 'analysis': [{'lex': 'муж', 'gr': 'S,муж,од=(вин,ед|род,ед)'}]}
# {'text': ' '}
# {'text': 'Мэттью', 'analysis': [{'lex': 'мэттью', 'gr': 'S,имя,мж,од=(пр,мн|пр,ед|вин,мн|вин,ед|дат,мн|дат,ед|род,мн|род,ед|твор,мн|твор,ед|им,мн|им,ед)'}]}
# {'text': ' '}
# {'text': 'Барни', 'analysis': [{'lex': 'барни', 'gr': 'S,имя,муж,од=(пр,мн|пр,ед|вин,мн|вин,ед|дат,мн|дат,ед|род,мн|род,ед|твор,мн|твор,ед|им,мн|им,ед)'}]}
# {'text': ', '}
# {'text': 'саундтрек', 'analysis': [{'lex': 'саундтрек', 'gr': 'S,муж,неод=(вин,ед|им,ед)'}]}
# {'text': ' '}
# {'text': 'к', 'analysis': [{'lex': 'к', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'которому', 'analysis': [{'lex': 'который', 'gr': 'APRO=(дат,ед,муж|дат,ед,сред)'}]}
# {'text': ' '}
# {'text': 'был', 'analysis': [{'lex': 'быть', 'gr': 'V,нп=прош,ед,изъяв,муж,несов'}]}
# {'text': ' '}
# {'text': 'выпущен', 'analysis': [{'lex': 'выпускать', 'gr': 'V=прош,ед,прич,кр,муж,сов,страд'}]}
# {'text': ' '}
# {'text': 'отдельным', 'analysis': [{'lex': 'отдельный', 'gr': 'A=(дат,мн,полн|твор,ед,полн,муж|твор,ед,полн,сред)'}]}
# {'text': ' '}
# {'text': 'одноимённым', 'analysis': [{'lex': 'одноименный', 'gr': 'A=(дат,мн,полн|твор,ед,полн,муж|твор,ед,полн,сред)'}]}
# {'text': ' '}
# {'text': 'альбомом', 'analysis': [{'lex': 'альбом', 'gr': 'S,муж,неод=твор,ед'}]}
# {'text': '. '}
# {'text': 'В', 'analysis': [{'lex': 'в', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': '2010'}
# {'text': ' '}
# {'text': 'году', 'analysis': [{'lex': 'год', 'gr': 'S,муж,неод=(дат,ед|местн,ед)'}]}
# {'text': ' '}
# {'text': 'Бьорк', 'analysis': [{'lex': 'бьорк', 'qual': 'bastard', 'gr': 'S,муж,од=им,ед'}]}
# {'text': ' '}
# {'text': 'получила', 'analysis': [{'lex': 'получать', 'gr': 'V,пе=прош,ед,изъяв,жен,сов'}]}
# {'text': ' '}
# {'text': 'премию', 'analysis': [{'lex': 'премия', 'gr': 'S,жен,неод=вин,ед'}]}
# {'text': ' «'}
# {'text': 'Polar', 'analysis': []}
# {'text': ' '}
# {'text': 'Music', 'analysis': []}
# {'text': ' '}
# {'text': 'Prize', 'analysis': []}
# {'text': '» '}
# {'text': 'от', 'analysis': [{'lex': 'от', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'Шведской', 'analysis': [{'lex': 'шведский', 'gr': 'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)'}]}
# {'text': ' '}
# {'text': 'королевской', 'analysis': [{'lex': 'королевский', 'gr': 'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)'}]}
# {'text': ' '}
# {'text': 'академии', 'analysis': [{'lex': 'академия', 'gr': 'S,жен,неод=(пр,ед|вин,мн|дат,ед|род,ед|им,мн)'}]}
# {'text': ' '}
# {'text': 'музыки', 'analysis': [{'lex': 'музыка', 'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}]}
# {'text': ' '}
# {'text': 'за', 'analysis': [{'lex': 'за', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'её', 'analysis': [{'lex': 'ее', 'gr': 'APRO=(пр,мн|дат,мн|род,мн|твор,мн|им,мн|им,ед,жен|вин,ед,муж,од|род,ед,муж|род,ед,сред|вин,ед,сред|им,ед,сред|пр,ед,жен|дат,ед,жен|род,ед,жен|твор,ед,жен|пр,ед,муж|пр,ед,сред|дат,ед,муж|дат,ед,сред|вин,ед,жен|вин,мн,неод|вин,ед,муж,неод|им,ед,муж|твор,ед,муж|твор,ед,сред|вин,мн,од|пр,мн,сред|вин,мн,сред|дат,мн,сред|род,мн,сред|твор,мн,сред|им,мн,сред|пр,мн,муж|вин,мн,муж|вин,ед,муж|дат,мн,муж)'}]}
# {'text': ' «'}
# {'text': 'глубоко', 'analysis': [{'lex': 'глубоко', 'gr': 'ADV='}]}
# {'text': ' '}
# {'text': 'личные', 'analysis': [{'lex': 'личный', 'gr': 'A=(вин,мн,полн,неод|им,мн,полн)'}]}
# {'text': ' '}
# {'text': 'музыку', 'analysis': [{'lex': 'музыка', 'gr': 'S,жен,неод=вин,ед'}]}
# {'text': ' '}
# {'text': 'и', 'analysis': [{'lex': 'и', 'gr': 'CONJ='}]}
# {'text': ' '}
# {'text': 'слова', 'analysis': [{'lex': 'слово', 'gr': 'S,сред,неод=(вин,мн|род,ед|им,мн)'}]}
# {'text': ', '}
# {'text': 'её', 'analysis': [{'lex': 'ее', 'gr': 'APRO=(пр,мн|дат,мн|род,мн|твор,мн|им,мн|им,ед,жен|вин,ед,муж,од|род,ед,муж|род,ед,сред|вин,ед,сред|им,ед,сред|пр,ед,жен|дат,ед,жен|род,ед,жен|твор,ед,жен|пр,ед,муж|пр,ед,сред|дат,ед,муж|дат,ед,сред|вин,ед,жен|вин,мн,неод|вин,ед,муж,неод|им,ед,муж|твор,ед,муж|твор,ед,сред|вин,мн,од|пр,мн,сред|вин,мн,сред|дат,мн,сред|род,мн,сред|твор,мн,сред|им,мн,сред|пр,мн,муж|вин,мн,муж|вин,ед,муж|дат,мн,муж)'}]}
# {'text': ' '}
# {'text': 'точные', 'analysis': [{'lex': 'точный', 'gr': 'A=(вин,мн,полн,неод|им,мн,полн)'}]}
# {'text': ' '}
# {'text': 'аранжировки', 'analysis': [{'lex': 'аранжировка', 'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}]}
# {'text': ' '}
# {'text': 'и', 'analysis': [{'lex': 'и', 'gr': 'CONJ='}]}
# {'text': ' '}
# {'text': 'её', 'analysis': [{'lex': 'ее', 'gr': 'APRO=(пр,мн|дат,мн|род,мн|твор,мн|им,мн|им,ед,жен|вин,ед,муж,од|род,ед,муж|род,ед,сред|вин,ед,сред|им,ед,сред|пр,ед,жен|дат,ед,жен|род,ед,жен|твор,ед,жен|пр,ед,муж|пр,ед,сред|дат,ед,муж|дат,ед,сред|вин,ед,жен|вин,мн,неод|вин,ед,муж,неод|им,ед,муж|твор,ед,муж|твор,ед,сред|вин,мн,од|пр,мн,сред|вин,мн,сред|дат,мн,сред|род,мн,сред|твор,мн,сред|им,мн,сред|пр,мн,муж|вин,мн,муж|вин,ед,муж|дат,мн,муж)'}]}
# {'text': ' '}
# {'text': 'уникальный', 'analysis': [{'lex': 'уникальный', 'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)'}]}
# {'text': ' '}
# {'text': 'голос', 'analysis': [{'lex': 'голос', 'gr': 'S,муж,неод=(вин,ед|им,ед)'}]}
# {'text': '»'}
# {'text': '. '}
# {'text': 'Всего', 'analysis': [{'lex': 'всего', 'gr': 'PART='}]}
# {'text': ' '}
# {'text': 'у', 'analysis': [{'lex': 'у', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'артистки', 'analysis': [{'lex': 'артистка', 'gr': 'S,жен,од=(род,ед|им,мн)'}]}
# {'text': ' '}
# {'text': 'более', 'analysis': [{'lex': 'много', 'gr': 'ADV=срав'}]}
# {'text': ' '}
# {'text': 'ста', 'analysis': [{'lex': 'сто', 'gr': 'NUM=(пр|дат|род|твор)'}]}
# {'text': ' '}
# {'text': 'наград', 'analysis': [{'lex': 'награда', 'gr': 'S,жен,неод=род,мн'}]}
# {'text': ' '}
# {'text': 'и', 'analysis': [{'lex': 'и', 'gr': 'CONJ='}]}
# {'text': ' '}
# {'text': 'двухсот', 'analysis': [{'lex': 'двести', 'gr': 'NUM=род'}]}
# {'text': ' '}
# {'text': 'номинаций', 'analysis': [{'lex': 'номинация', 'gr': 'S,жен,неод=род,мн'}]}
# {'text': '. '}
# {'text': 'Её', 'analysis': [{'lex': 'она', 'gr': 'SPRO,ед,3-л,жен=(вин|род)'}]}
# {'text': ' '}
# {'text': 'альбом', 'analysis': [{'lex': 'альбом', 'gr': 'S,муж,неод=(вин,ед|им,ед)'}]}
# {'text': ' «'}
# {'text': 'Biophilia', 'analysis': []}
# {'text': '» ('}
# {'text': '2011'}
# {'text': ') '}
# {'text': 'был', 'analysis': [{'lex': 'быть', 'gr': 'V,нп=прош,ед,изъяв,муж,несов'}]}
# {'text': ' '}
# {'text': 'первым', 'analysis': [{'lex': 'первый', 'gr': 'ANUM=(дат,мн|твор,ед,муж|твор,ед,сред)'}]}
# {'text': ' '}
# {'text': 'альбомом', 'analysis': [{'lex': 'альбом', 'gr': 'S,муж,неод=твор,ед'}]}
# {'text': ' '}
# {'text': 'в', 'analysis': [{'lex': 'в', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'формате', 'analysis': [{'lex': 'формат', 'gr': 'S,муж,неод=пр,ед'}]}
# {'text': ' '}
# {'text': 'мобильных', 'analysis': [{'lex': 'мобильный', 'gr': 'A=(пр,мн,полн|вин,мн,полн,од|род,мн,полн)'}]}
# {'text': ' '}
# {'text': 'приложений', 'analysis': [{'lex': 'приложение', 'gr': 'S,сред,неод=род,мн'}]}
# {'text': ' '}
# {'text': 'и', 'analysis': [{'lex': 'и', 'gr': 'CONJ='}]}
# {'text': ' '}
# {'text': 'позднее', 'analysis': [{'lex': 'поздно', 'gr': 'ADV=срав'}]}
# {'text': ' '}
# {'text': 'его', 'analysis': [{'lex': 'он', 'gr': 'SPRO,ед,3-л,муж=(вин|род)'}]}
# {'text': ' '}
# {'text': 'включили', 'analysis': [{'lex': 'включать', 'gr': 'V,пе=прош,мн,изъяв,сов'}]}
# {'text': ' '}
# {'text': 'в', 'analysis': [{'lex': 'в', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'состав', 'analysis': [{'lex': 'состав', 'gr': 'S,муж,неод=(вин,ед|им,ед)'}]}
# {'text': ' '}
# {'text': 'постоянной', 'analysis': [{'lex': 'постоянный', 'gr': 'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)'}]}
# {'text': ' '}
# {'text': 'коллекции', 'analysis': [{'lex': 'коллекция', 'gr': 'S,жен,неод=(пр,ед|вин,мн|дат,ед|род,ед|им,мн)'}]}
# {'text': ' '}
# {'text': 'Нью-Йоркского', 'analysis': [{'lex': 'нью-йоркский', 'gr': 'A=(вин,ед,полн,муж,од|род,ед,полн,муж|род,ед,полн,сред)'}]}
# {'text': ' '}
# {'text': 'музея', 'analysis': [{'lex': 'музей', 'gr': 'S,муж,неод=род,ед'}]}
# {'text': ' '}
# {'text': 'Современного', 'analysis': [{'lex': 'современный', 'gr': 'A=(вин,ед,полн,муж,од|род,ед,полн,муж|род,ед,полн,сред)'}]}
# {'text': ' '}
# {'text': 'искусства', 'analysis': [{'lex': 'искусство', 'gr': 'S,сред,неод=(вин,мн|род,ед|им,мн)'}]}
# {'text': ' ('}
# {'text': 'MoMA', 'analysis': []}
# {'text': '), '}
# {'text': 'почти', 'analysis': [{'lex': 'почти', 'gr': 'ADV='}]}
# {'text': ' '}
# {'text': 'через', 'analysis': [{'lex': 'через', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'год', 'analysis': [{'lex': 'год', 'gr': 'S,муж,неод=(вин,ед|им,ед)'}]}
# {'text': ' '}
# {'text': 'там', 'analysis': [{'lex': 'там', 'gr': 'ADVPRO='}]}
# {'text': ' '}
# {'text': 'прошла', 'analysis': [{'lex': 'проходить', 'gr': 'V,нп=прош,ед,изъяв,жен,сов'}]}
# {'text': ' '}
# {'text': 'выставка', 'analysis': [{'lex': 'выставка', 'gr': 'S,жен,неод=им,ед'}]}
# {'text': ' '}
# {'text': 'по', 'analysis': [{'lex': 'по', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'мотивам', 'analysis': [{'lex': 'мотив', 'gr': 'S,муж,неод=дат,мн'}]}
# {'text': ' '}
# {'text': 'творчества', 'analysis': [{'lex': 'творчество', 'gr': 'S,сред,неод=(вин,мн|род,ед|им,мн)'}]}
# {'text': ' '}
# {'text': 'Бьорк', 'analysis': [{'lex': 'бьорк', 'qual': 'bastard', 'gr': 'S,муж,од=им,ед'}]}
# {'text': ', '}
# {'text': 'которая', 'analysis': [{'lex': 'который', 'gr': 'APRO=им,ед,жен'}]}
# {'text': ' '}
# {'text': 'охватила', 'analysis': [{'lex': 'охватывать', 'gr': 'V,пе=прош,ед,изъяв,жен,сов'}]}
# {'text': ' '}
# {'text': 'весь', 'analysis': [{'lex': 'весь', 'gr': 'APRO=(вин,ед,муж,неод|им,ед,муж)'}]}
# {'text': ' '}
# {'text': 'период', 'analysis': [{'lex': 'период', 'gr': 'S,муж,неод=(вин,ед|им,ед)'}]}
# {'text': ' '}
# {'text': 'её', 'analysis': [{'lex': 'ее', 'gr': 'APRO=(пр,мн|дат,мн|род,мн|твор,мн|им,мн|им,ед,жен|вин,ед,муж,од|род,ед,муж|род,ед,сред|вин,ед,сред|им,ед,сред|пр,ед,жен|дат,ед,жен|род,ед,жен|твор,ед,жен|пр,ед,муж|пр,ед,сред|дат,ед,муж|дат,ед,сред|вин,ед,жен|вин,мн,неод|вин,ед,муж,неод|им,ед,муж|твор,ед,муж|твор,ед,сред|вин,мн,од|пр,мн,сред|вин,мн,сред|дат,мн,сред|род,мн,сред|твор,мн,сред|им,мн,сред|пр,мн,муж|вин,мн,муж|вин,ед,муж|дат,мн,муж)'}]}
# {'text': ' '}
# {'text': 'сольной', 'analysis': [{'lex': 'сольный', 'gr': 'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)'}]}
# {'text': ' '}
# {'text': 'карьеры', 'analysis': [{'lex': 'карьера', 'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}]}
# {'text': '. '}
# {'text': 'Издание', 'analysis': [{'lex': 'издание', 'gr': 'S,сред,неод=(вин,ед|им,ед)'}]}
# {'text': ' «'}
# {'text': 'Time', 'analysis': []}
# {'text': '» '}
# {'text': 'включило', 'analysis': [{'lex': 'включать', 'gr': 'V,пе=прош,ед,изъяв,сред,сов'}]}
# {'text': ' '}
# {'text': 'Бьорк', 'analysis': [{'lex': 'бьорк', 'qual': 'bastard', 'gr': 'S,муж,од=им,ед'}]}
# {'text': ' '}
# {'text': 'в', 'analysis': [{'lex': 'в', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'раздел', 'analysis': [{'lex': 'раздел', 'gr': 'S,муж,неод=(вин,ед|им,ед)'}]}
# {'text': ' «'}
# {'text': 'иконы', 'analysis': [{'lex': 'икона', 'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}]}
# {'text': '» '}
# {'text': 'как', 'analysis': [{'lex': 'как', 'gr': 'CONJ='}]}
# {'text': ' '}
# {'text': 'одну', 'analysis': [{'lex': 'один', 'gr': 'APRO=вин,ед,жен'}]}
# {'text': ' '}
# {'text': 'из', 'analysis': [{'lex': 'из', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': '100'}
# {'text': ' '}
# {'text': 'самых', 'analysis': [{'lex': 'самый', 'gr': 'APRO=(пр,мн|род,мн|вин,мн,од)'}]}
# {'text': ' '}
# {'text': 'влиятельных', 'analysis': [{'lex': 'влиятельный', 'gr': 'A=(пр,мн,полн|вин,мн,полн,од|род,мн,полн)'}]}
# {'text': ' '}
# {'text': 'людей', 'analysis': [{'lex': 'человек', 'gr': 'S,муж,од=(вин,мн|род,мн)'}]}
# {'text': ' '}
# {'text': 'в', 'analysis': [{'lex': 'в', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'мире', 'analysis': [{'lex': 'мир', 'gr': 'S,муж,неод=пр,ед'}]}
# {'text': ', '}
# {'text': 'назвав', 'analysis': [{'lex': 'называть', 'gr': 'V,пе=прош,деепр,сов'}]}
# {'text': ' '}
# {'text': 'её', 'analysis': [{'lex': 'ее', 'gr': 'APRO=(пр,мн|дат,мн|род,мн|твор,мн|им,мн|им,ед,жен|вин,ед,муж,од|род,ед,муж|род,ед,сред|вин,ед,сред|им,ед,сред|пр,ед,жен|дат,ед,жен|род,ед,жен|твор,ед,жен|пр,ед,муж|пр,ед,сред|дат,ед,муж|дат,ед,сред|вин,ед,жен|вин,мн,неод|вин,ед,муж,неод|им,ед,муж|твор,ед,муж|твор,ед,сред|вин,мн,од|пр,мн,сред|вин,мн,сред|дат,мн,сред|род,мн,сред|твор,мн,сред|им,мн,сред|пр,мн,муж|вин,мн,муж|вин,ед,муж|дат,мн,муж)'}]}
# {'text': ' «'}
# {'text': 'верховной', 'analysis': [{'lex': 'верховный', 'gr': 'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)'}]}
# {'text': ' '}
# {'text': 'жрицей', 'analysis': [{'lex': 'жрица', 'gr': 'S,жен,од=твор,ед'}]}
# {'text': ' '}
# {'text': 'искусств', 'analysis': [{'lex': 'искусство', 'gr': 'S,сред,неод=род,мн'}]}
# {'text': '», '}
# {'text': 'небольшой', 'analysis': [{'lex': 'небольшой', 'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж|пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)'}]}
# {'text': ' '}
# {'text': 'текст', 'analysis': [{'lex': 'текст', 'gr': 'S,муж,неод=(вин,ед|им,ед)'}]}
# {'text': ' '}
# {'text': 'к', 'analysis': [{'lex': 'к', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'нему', 'analysis': [{'lex': 'он', 'gr': 'SPRO,ед,3-л,муж=дат'}]}
# {'text': ' '}
# {'text': 'написала', 'analysis': [{'lex': 'написать', 'gr': 'V,сов,пе=прош,ед,изъяв,жен'}]}
# {'text': ' '}
# {'text': 'Марина', 'analysis': [{'lex': 'марина', 'gr': 'S,имя,жен,од=им,ед'}]}
# {'text': ' '}
# {'text': 'Абрамович', 'analysis': [{'lex': 'абрамович', 'gr': 'S,фам,муж,од=им,ед'}]}
# {'text': ', '}
# {'text': 'утверждая', 'analysis': [{'lex': 'утверждать', 'gr': 'V=непрош,деепр,несов,пе'}]}
# {'text': ', '}
# {'text': 'что', 'analysis': [{'lex': 'что', 'gr': 'CONJ='}]}
# {'text': ' «'}
# {'text': 'Бьорк', 'analysis': [{'lex': 'бьорк', 'qual': 'bastard', 'gr': 'S,муж,од=им,ед'}]}
# {'text': ' '}
# {'text': 'учит', 'analysis': [{'lex': 'учить', 'gr': 'V,несов,пе=непрош,ед,изъяв,3-л'}]}
# {'text': ' '}
# {'text': 'нас', 'analysis': [{'lex': 'мы', 'gr': 'SPRO,мн,1-л=(пр|вин|род)'}]}
# {'text': ' '}
# {'text': 'храбрости', 'analysis': [{'lex': 'храбрость', 'gr': 'S,жен,неод=(пр,ед|вин,мн|дат,ед|род,ед|им,мн)'}]}
# {'text': ' '}
# {'text': 'быть', 'analysis': [{'lex': 'быть', 'gr': 'V,нп=инф,несов'}]}
# {'text': ' '}
# {'text': 'самими', 'analysis': [{'lex': 'сам', 'gr': 'APRO=твор,мн'}]}
# {'text': ' '}
# {'text': 'собой', 'analysis': [{'lex': 'себя', 'gr': 'SPRO=твор'}]}
# {'text': '»'}
# {'text': '.'}
# {'text': '\n'}
# {'text': 'Музыкальные', 'analysis': [{'lex': 'музыкальный', 'gr': 'A=(вин,мн,полн,неод|им,мн,полн)'}]}
# {'text': ' '}
# {'text': 'критики', 'analysis': [{'lex': 'критик', 'gr': 'S,муж,од=им,мн'}]}
# {'text': ' '}
# {'text': 'всегда', 'analysis': [{'lex': 'всегда', 'gr': 'ADVPRO='}]}
# {'text': ' '}
# {'text': 'отстаивали', 'analysis': [{'lex': 'отстаивать', 'gr': 'V=прош,мн,изъяв,несов,пе'}]}
# {'text': ' '}
# {'text': 'работу', 'analysis': [{'lex': 'работа', 'gr': 'S,жен,неод=вин,ед'}]}
# {'text': ' '}
# {'text': 'Бьорк', 'analysis': [{'lex': 'бьорк', 'qual': 'bastard', 'gr': 'S,муж,од=им,ед'}]}
# {'text': ', '}
# {'text': 'восхваляя', 'analysis': [{'lex': 'восхвалять', 'gr': 'V,пе=непрош,деепр,несов'}]}
# {'text': ' '}
# {'text': 'её', 'analysis': [{'lex': 'ее', 'gr': 'APRO=(пр,мн|дат,мн|род,мн|твор,мн|им,мн|им,ед,жен|вин,ед,муж,од|род,ед,муж|род,ед,сред|вин,ед,сред|им,ед,сред|пр,ед,жен|дат,ед,жен|род,ед,жен|твор,ед,жен|пр,ед,муж|пр,ед,сред|дат,ед,муж|дат,ед,сред|вин,ед,жен|вин,мн,неод|вин,ед,муж,неод|им,ед,муж|твор,ед,муж|твор,ед,сред|вин,мн,од|пр,мн,сред|вин,мн,сред|дат,мн,сред|род,мн,сред|твор,мн,сред|им,мн,сред|пр,мн,муж|вин,мн,муж|вин,ед,муж|дат,мн,муж)'}]}
# {'text': ' '}
# {'text': 'инновационный', 'analysis': [{'lex': 'инновационный', 'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)'}]}
# {'text': ' '}
# {'text': 'подход', 'analysis': [{'lex': 'подход', 'gr': 'S,муж,неод=(вин,ед|им,ед)'}]}
# {'text': ' '}
# {'text': 'к', 'analysis': [{'lex': 'к', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'пению', 'analysis': [{'lex': 'пение', 'gr': 'S,сред,неод=дат,ед'}]}
# {'text': ' '}
# {'text': 'и', 'analysis': [{'lex': 'и', 'gr': 'CONJ='}]}
# {'text': ' '}
# {'text': 'композиторству', 'analysis': [{'lex': 'композиторство', 'qual': 'bastard', 'gr': 'S,сред,неод=дат,ед'}]}
# {'text': ', '}
# {'text': 'её', 'analysis': [{'lex': 'ее', 'gr': 'APRO=(пр,мн|дат,мн|род,мн|твор,мн|им,мн|им,ед,жен|вин,ед,муж,од|род,ед,муж|род,ед,сред|вин,ед,сред|им,ед,сред|пр,ед,жен|дат,ед,жен|род,ед,жен|твор,ед,жен|пр,ед,муж|пр,ед,сред|дат,ед,муж|дат,ед,сред|вин,ед,жен|вин,мн,неод|вин,ед,муж,неод|им,ед,муж|твор,ед,муж|твор,ед,сред|вин,мн,од|пр,мн,сред|вин,мн,сред|дат,мн,сред|род,мн,сред|твор,мн,сред|им,мн,сред|пр,мн,муж|вин,мн,муж|вин,ед,муж|дат,мн,муж)'}]}
# {'text': ' '}
# {'text': 'передовое', 'analysis': [{'lex': 'передовой', 'gr': 'A=(вин,ед,полн,сред|им,ед,полн,сред)'}]}
# {'text': ' '}
# {'text': 'использование', 'analysis': [{'lex': 'использование', 'gr': 'S,сред,неод=(вин,ед|им,ед)'}]}
# {'text': ' '}
# {'text': 'электронных', 'analysis': [{'lex': 'электронный', 'gr': 'A=(пр,мн,полн|вин,мн,полн,од|род,мн,полн)'}]}
# {'text': ' '}
# {'text': 'битов', 'analysis': [{'lex': 'бит', 'gr': 'S,муж,неод=род,мн'}]}
# {'text': ', '}
# {'text': 'прогрессивные', 'analysis': [{'lex': 'прогрессивный', 'gr': 'A=(вин,мн,полн,неод|им,мн,полн)'}]}
# {'text': ' '}
# {'text': 'музыкальные', 'analysis': [{'lex': 'музыкальный', 'gr': 'A=(вин,мн,полн,неод|им,мн,полн)'}]}
# {'text': ' '}
# {'text': 'видео', 'analysis': [{'lex': 'видео', 'gr': 'S,сред,неод=(пр,мн|пр,ед|вин,мн|вин,ед|дат,мн|дат,ед|род,мн|род,ед|твор,мн|твор,ед|им,мн|им,ед)'}]}
# {'text': ', '}
# {'text': 'и', 'analysis': [{'lex': 'и', 'gr': 'CONJ='}]}
# {'text': ' '}
# {'text': 'прежде', 'analysis': [{'lex': 'прежде', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'всего', 'analysis': [{'lex': 'все', 'gr': 'SPRO,ед,сред,неод=род'}]}
# {'text': ' — '}
# {'text': 'её', 'analysis': [{'lex': 'ее', 'gr': 'APRO=(пр,мн|дат,мн|род,мн|твор,мн|им,мн|им,ед,жен|вин,ед,муж,од|род,ед,муж|род,ед,сред|вин,ед,сред|им,ед,сред|пр,ед,жен|дат,ед,жен|род,ед,жен|твор,ед,жен|пр,ед,муж|пр,ед,сред|дат,ед,муж|дат,ед,сред|вин,ед,жен|вин,мн,неод|вин,ед,муж,неод|им,ед,муж|твор,ед,муж|твор,ед,сред|вин,мн,од|пр,мн,сред|вин,мн,сред|дат,мн,сред|род,мн,сред|твор,мн,сред|им,мн,сред|пр,мн,муж|вин,мн,муж|вин,ед,муж|дат,мн,муж)'}]}
# {'text': ' '}
# {'text': 'уникальный', 'analysis': [{'lex': 'уникальный', 'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)'}]}
# {'text': ' '}
# {'text': 'голос', 'analysis': [{'lex': 'голос', 'gr': 'S,муж,неод=(вин,ед|им,ед)'}]}
# {'text': ', '}
# {'text': 'описывая', 'analysis': [{'lex': 'описывать', 'gr': 'V,пе=непрош,деепр,несов'}]}
# {'text': ' '}
# {'text': 'её', 'analysis': [{'lex': 'она', 'gr': 'SPRO,ед,3-л,жен=(вин|род)'}]}
# {'text': ' '}
# {'text': 'как', 'analysis': [{'lex': 'как', 'gr': 'CONJ='}]}
# {'text': ' «'}
# {'text': 'самого', 'analysis': [{'lex': 'самый', 'gr': 'APRO=(вин,ед,муж,од|род,ед,муж|род,ед,сред)'}]}
# {'text': ' '}
# {'text': 'важного', 'analysis': [{'lex': 'важный', 'gr': 'A=(вин,ед,полн,муж,од|род,ед,полн,муж|род,ед,полн,сред)'}]}
# {'text': ' '}
# {'text': 'и', 'analysis': [{'lex': 'и', 'gr': 'CONJ='}]}
# {'text': ' '}
# {'text': 'дальновидного', 'analysis': [{'lex': 'дальновидный', 'gr': 'A=(вин,ед,полн,муж,од|род,ед,полн,муж|род,ед,полн,сред)'}]}
# {'text': ' '}
# {'text': 'музыканта', 'analysis': [{'lex': 'музыкант', 'gr': 'S,муж,од=(вин,ед|род,ед)'}]}
# {'text': ' '}
# {'text': 'своего', 'analysis': [{'lex': 'свой', 'gr': 'APRO=(вин,ед,муж,од|род,ед,муж|род,ед,сред)'}]}
# {'text': ' '}
# {'text': 'поколения', 'analysis': [{'lex': 'поколение', 'gr': 'S,сред,неод=(вин,мн|род,ед|им,мн)'}]}
# {'text': '»'}
# {'text': '.'}
# {'text': '['}
# {'text': '2'}
# {'text': ']['}
# {'text': '3'}
# {'text': ']['}
# {'text': '4'}
# {'text': ']\n'}
# {'text': 'Содержание', 'analysis': [{'lex': 'содержание', 'gr': 'S,сред,неод=(вин,ед|им,ед)'}]}
# {'text': '  ['}
# {'text': 'скрыть', 'analysis': [{'lex': 'скрывать', 'gr': 'V=инф,сов'}]}
# {'text': '] \n'}
# {'text': '1'}
# {'text': '\t'}
# {'text': 'Ранние', 'analysis': [{'lex': 'ранний', 'gr': 'A=(вин,мн,полн,неод|им,мн,полн)'}]}
# {'text': ' '}
# {'text': 'годы', 'analysis': [{'lex': 'год', 'gr': 'S,муж,неод=(вин,мн|им,мн)'}]}
# {'text': '\n'}
# {'text': '2'}
# {'text': '\t'}
# {'text': 'Сольная', 'analysis': [{'lex': 'сольный', 'gr': 'A=им,ед,полн,жен'}]}
# {'text': ' '}
# {'text': 'карьера', 'analysis': [{'lex': 'карьера', 'gr': 'S,жен,неод=им,ед'}]}
# {'text': '\n'}
# {'text': '2.1'}
# {'text': '\t'}
# {'text': 'Начало', 'analysis': [{'lex': 'начало', 'gr': 'S,сред,неод=(вин,ед|им,ед)'}]}
# {'text': ' '}
# {'text': 'карьеры', 'analysis': [{'lex': 'карьера', 'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}]}
# {'text': ', '}
# {'text': 'Debut', 'analysis': []}
# {'text': ' '}
# {'text': 'и', 'analysis': [{'lex': 'и', 'gr': 'CONJ='}]}
# {'text': ' '}
# {'text': 'Post', 'analysis': []}
# {'text': ' ('}
# {'text': '1992'}
# {'text': '—'}
# {'text': '1996'}
# {'text': ')\n'}
# {'text': '2.2'}
# {'text': '\t'}
# {'text': 'Homogenic', 'analysis': []}
# {'text': ' '}
# {'text': 'и', 'analysis': [{'lex': 'и', 'gr': 'CONJ='}]}
# {'text': ' '}
# {'text': 'Vespertine', 'analysis': []}
# {'text': ' ('}
# {'text': '1997'}
# {'text': '—'}
# {'text': '2002'}
# {'text': ')\n'}
# {'text': '2.3'}
# {'text': '\t'}
# {'text': 'Medúlla', 'analysis': []}
# {'text': ' ('}
# {'text': '2003'}
# {'text': '—'}
# {'text': '2006'}
# {'text': ')\n'}
# {'text': '2.4'}
# {'text': '\t'}
# {'text': 'Volta', 'analysis': []}
# {'text': ' ('}
# {'text': '2007'}
# {'text': '—'}
# {'text': '2010'}
# {'text': ')\n'}
# {'text': '2.5'}
# {'text': '\t'}
# {'text': 'Biophilia', 'analysis': []}
# {'text': ' ('}
# {'text': '2011'}
# {'text': '—'}
# {'text': '2014'}
# {'text': ')\n'}
# {'text': '2.6'}
# {'text': '\t'}
# {'text': 'Vulnicura', 'analysis': []}
# {'text': ' ('}
# {'text': '2015'}
# {'text': '—'}
# {'text': '2016'}
# {'text': ')\n'}
# {'text': '2.7'}
# {'text': '\t'}
# {'text': 'Utopia', 'analysis': []}
# {'text': ' ('}
# {'text': '2017'}
# {'text': '—'}
# {'text': 'настоящее', 'analysis': [{'lex': 'настоящий', 'gr': 'A=(вин,ед,полн,сред|им,ед,полн,сред|срав)'}]}
# {'text': ' '}
# {'text': 'время', 'analysis': [{'lex': 'время', 'gr': 'S,сред,неод=(вин,ед|им,ед)'}]}
# {'text': ')\n'}
# {'text': '3'}
# {'text': '\t'}
# {'text': 'Бьорк', 'analysis': [{'lex': 'бьорк', 'qual': 'bastard', 'gr': 'S,муж,од=им,ед'}]}
# {'text': ' '}
# {'text': 'в', 'analysis': [{'lex': 'в', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'кино', 'analysis': [{'lex': 'кино', 'gr': 'S,сред,неод=(пр,мн|пр,ед|вин,мн|вин,ед|дат,мн|дат,ед|род,мн|род,ед|твор,мн|твор,ед|им,мн|им,ед)'}]}
# {'text': '\n'}
# {'text': '4'}
# {'text': '\t'}
# {'text': 'Личная', 'analysis': [{'lex': 'личный', 'gr': 'A=им,ед,полн,жен'}]}
# {'text': ' '}
# {'text': 'жизнь', 'analysis': [{'lex': 'жизнь', 'gr': 'S,жен,неод=(вин,ед|им,ед)'}]}
# {'text': '\n'}
# {'text': '5'}
# {'text': '\t'}
# {'text': 'Дискография', 'analysis': [{'lex': 'дискография', 'gr': 'S,жен,неод=им,ед'}]}
# {'text': '\n'}
# {'text': '6'}
# {'text': '\t'}
# {'text': 'Фильмография', 'analysis': [{'lex': 'фильмография', 'gr': 'S,жен,неод=им,ед'}]}
# {'text': ', '}
# {'text': 'включая', 'analysis': [{'lex': 'включая', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'камео', 'analysis': [{'lex': 'камео', 'qual': 'bastard', 'gr': 'S,гео,ед,муж,неод=(пр|вин|дат|род|твор|им)'}]}
# {'text': '\n'}
# {'text': '7'}
# {'text': '\t'}
# {'text': 'См', 'analysis': [{'lex': 'см', 'gr': 'S,муж,неод=(пр,мн|пр,ед|вин,мн|вин,ед|дат,мн|дат,ед|род,мн|род,ед|твор,мн|твор,ед|им,мн|им,ед)'}]}
# {'text': '.'}
# {'text': ' '}
# {'text': 'также', 'analysis': [{'lex': 'также', 'gr': 'ADV='}]}
# {'text': '\n'}
# {'text': '8'}
# {'text': '\t'}
# {'text': 'Примечания', 'analysis': [{'lex': 'примечание', 'gr': 'S,сред,неод=(вин,мн|род,ед|им,мн)'}]}
# {'text': '\n'}
# {'text': '9'}
# {'text': '\t'}
# {'text': 'Ссылки', 'analysis': [{'lex': 'ссылка', 'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}]}
# {'text': '\n'}
# {'text': 'Ранние', 'analysis': [{'lex': 'ранний', 'gr': 'A=(вин,мн,полн,неод|им,мн,полн)'}]}
# {'text': ' '}
# {'text': 'годы', 'analysis': [{'lex': 'год', 'gr': 'S,муж,неод=(вин,мн|им,мн)'}]}
# {'text': '['}
# {'text': 'править', 'analysis': [{'lex': 'править', 'gr': 'V,несов,пе=инф'}]}
# {'text': ' | '}
# {'text': 'править', 'analysis': [{'lex': 'править', 'gr': 'V,несов,пе=инф'}]}
# {'text': ' '}
# {'text': 'код', 'analysis': [{'lex': 'код', 'gr': 'S,муж,неод=(вин,ед|им,ед)'}]}
# {'text': ']\n'}
# {'text': 'Музыкальная', 'analysis': [{'lex': 'музыкальный', 'gr': 'A=им,ед,полн,жен'}]}
# {'text': ' '}
# {'text': 'карьера', 'analysis': [{'lex': 'карьера', 'gr': 'S,жен,неод=им,ед'}]}
# {'text': ' '}
# {'text': 'Бьорк', 'analysis': [{'lex': 'бьорк', 'qual': 'bastard', 'gr': 'S,муж,од=им,ед'}]}
# {'text': ' '}
# {'text': 'началась', 'analysis': [{'lex': 'начинаться', 'gr': 'V,нп=прош,ед,изъяв,жен,сов'}]}
# {'text': ', '}
# {'text': 'когда', 'analysis': [{'lex': 'когда', 'gr': 'CONJ='}]}
# {'text': ' '}
# {'text': 'ей', 'analysis': [{'lex': 'она', 'gr': 'SPRO,ед,3-л,жен=(дат|твор)'}]}
# {'text': ' '}
# {'text': 'было', 'analysis': [{'lex': 'быть', 'gr': 'V,нп=прош,ед,изъяв,сред,несов'}]}
# {'text': ' '}
# {'text': '11'}
# {'text': ' '}
# {'text': 'лет', 'analysis': [{'lex': 'год', 'gr': 'S,муж,неод=род,мн'}]}
# {'text': '. '}
# {'text': 'Один', 'analysis': [{'lex': 'один', 'gr': 'APRO=(вин,ед,муж,неод|им,ед,муж)'}]}
# {'text': ' '}
# {'text': 'из', 'analysis': [{'lex': 'из', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'учителей', 'analysis': [{'lex': 'учитель', 'gr': 'S,муж,од=(вин,мн|род,мн)'}]}
# {'text': ' '}
# {'text': 'послал', 'analysis': [{'lex': 'посылать', 'gr': 'V=прош,ед,изъяв,муж,сов'}]}
# {'text': ' '}
# {'text': 'запись', 'analysis': [{'lex': 'запись', 'gr': 'S,жен,неод=(вин,ед|им,ед)'}]}
# {'text': ' '}
# {'text': 'песни', 'analysis': [{'lex': 'песня', 'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}]}
# {'text': ' '}
# {'text': 'в', 'analysis': [{'lex': 'в', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'исполнении', 'analysis': [{'lex': 'исполнение', 'gr': 'S,сред,неод=пр,ед'}]}
# {'text': ' '}
# {'text': 'Бьорк', 'analysis': [{'lex': 'бьорк', 'qual': 'bastard', 'gr': 'S,муж,од=им,ед'}]}
# {'text': ' '}
# {'text': 'на', 'analysis': [{'lex': 'на', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'тогда', 'analysis': [{'lex': 'тогда', 'gr': 'ADVPRO='}]}
# {'text': ' '}
# {'text': 'ещё', 'analysis': [{'lex': 'еще', 'gr': 'ADV='}]}
# {'text': ' '}
# {'text': 'единственную', 'analysis': [{'lex': 'единственный', 'gr': 'A=вин,ед,полн,жен'}]}
# {'text': ' '}
# {'text': 'радиостанцию', 'analysis': [{'lex': 'радиостанция', 'gr': 'S,жен,неод=вин,ед'}]}
# {'text': ' '}
# {'text': 'Исландии', 'analysis': [{'lex': 'исландия', 'gr': 'S,гео,жен,неод=(пр,ед|вин,мн|дат,ед|род,ед|им,мн)'}]}
# {'text': ', '}
# {'text': 'которая', 'analysis': [{'lex': 'который', 'gr': 'APRO=им,ед,жен'}]}
# {'text': ' '}
# {'text': 'включила', 'analysis': [{'lex': 'включать', 'gr': 'V,пе=прош,ед,изъяв,жен,сов'}]}
# {'text': ' '}
# {'text': 'песню', 'analysis': [{'lex': 'песня', 'gr': 'S,жен,неод=вин,ед'}]}
# {'text': ' '}
# {'text': 'в', 'analysis': [{'lex': 'в', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'эфир', 'analysis': [{'lex': 'эфир', 'gr': 'S,муж,неод=(вин,ед|им,ед)'}]}
# {'text': '. '}
# {'text': 'После', 'analysis': [{'lex': 'после', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'этого', 'analysis': [{'lex': 'это', 'gr': 'SPRO,ед,сред,неод=род'}]}
# {'text': ' '}
# {'text': 'ей', 'analysis': [{'lex': 'она', 'gr': 'SPRO,ед,3-л,жен=(дат|твор)'}]}
# {'text': ' '}
# {'text': 'предложили', 'analysis': [{'lex': 'предлагать', 'gr': 'V,пе=прош,мн,изъяв,сов'}]}
# {'text': ' '}
# {'text': 'контракт', 'analysis': [{'lex': 'контракт', 'gr': 'S,муж,неод=(вин,ед|им,ед)'}]}
# {'text': ' '}
# {'text': 'на', 'analysis': [{'lex': 'на', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'запись', 'analysis': [{'lex': 'запись', 'gr': 'S,жен,неод=(вин,ед|им,ед)'}]}
# {'text': ' '}
# {'text': 'альбома', 'analysis': [{'lex': 'альбом', 'gr': 'S,муж,неод=род,ед'}]}
# {'text': ', '}
# {'text': 'и', 'analysis': [{'lex': 'и', 'gr': 'CONJ='}]}
# {'text': ' '}
# {'text': 'в', 'analysis': [{'lex': 'в', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': '1977'}
# {'text': ' '}
# {'text': 'она', 'analysis': [{'lex': 'она', 'gr': 'SPRO,ед,3-л,жен=им'}]}
# {'text': ' '}
# {'text': 'записала', 'analysis': [{'lex': 'записывать', 'gr': 'V,пе=прош,ед,изъяв,жен,сов'}]}
# {'text': ' '}
# {'text': 'свой', 'analysis': [{'lex': 'свой', 'gr': 'APRO=(вин,ед,муж,неод|им,ед,муж)'}]}
# {'text': ' '}
# {'text': 'дебютный', 'analysis': [{'lex': 'дебютный', 'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)'}]}
# {'text': ' '}
# {'text': 'альбом', 'analysis': [{'lex': 'альбом', 'gr': 'S,муж,неод=(вин,ед|им,ед)'}]}
# {'text': ' '}
# {'text': 'с', 'analysis': [{'lex': 'с', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'помощью', 'analysis': [{'lex': 'помощь', 'gr': 'S,жен,неод=твор,ед'}]}
# {'text': ' '}
# {'text': 'отчима', 'analysis': [{'lex': 'отчим', 'gr': 'S,муж,од=(вин,ед|род,ед)'}]}
# {'text': ', '}
# {'text': 'который', 'analysis': [{'lex': 'который', 'gr': 'APRO=(вин,ед,муж,неод|им,ед,муж)'}]}
# {'text': ' '}
# {'text': 'играл', 'analysis': [{'lex': 'играть', 'gr': 'V,несов,пе=прош,ед,изъяв,муж'}]}
# {'text': ' '}
# {'text': 'на', 'analysis': [{'lex': 'на', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'гитаре', 'analysis': [{'lex': 'гитара', 'gr': 'S,жен,неод=(пр,ед|дат,ед)'}]}
# {'text': '. '}
# {'text': 'На', 'analysis': [{'lex': 'на', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'альбоме', 'analysis': [{'lex': 'альбом', 'gr': 'S,муж,неод=пр,ед'}]}
# {'text': ' '}
# {'text': 'присутствуют', 'analysis': [{'lex': 'присутствовать', 'gr': 'V,несов,нп=непрош,мн,изъяв,3-л'}]}
# {'text': ' '}
# {'text': 'исландские', 'analysis': [{'lex': 'исландский', 'gr': 'A=(вин,мн,полн,неод|им,мн,полн)'}]}
# {'text': ' '}
# {'text': 'детские', 'analysis': [{'lex': 'детский', 'gr': 'A=(вин,мн,полн,неод|им,мн,полн)'}]}
# {'text': ' '}
# {'text': 'песни', 'analysis': [{'lex': 'песня', 'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}]}
# {'text': ' '}
# {'text': 'и', 'analysis': [{'lex': 'и', 'gr': 'CONJ='}]}
# {'text': ' '}
# {'text': 'кавер-версии', 'analysis': [{'lex': 'кавер-версия', 'gr': 'S,жен,неод=(пр,ед|вин,мн|дат,ед|род,ед|им,мн)'}]}
# {'text': ' '}
# {'text': 'таких', 'analysis': [{'lex': 'такой', 'gr': 'APRO=(пр,мн|род,мн|вин,мн,од)'}]}
# {'text': ' '}
# {'text': 'популярных', 'analysis': [{'lex': 'популярный', 'gr': 'A=(пр,мн,полн|вин,мн,полн,од|род,мн,полн)'}]}
# {'text': ' '}
# {'text': 'песен', 'analysis': [{'lex': 'песня', 'gr': 'S,жен,неод=род,мн'}]}
# {'text': ', '}
# {'text': 'как', 'analysis': [{'lex': 'как', 'gr': 'CONJ='}]}
# {'text': ' «'}
# {'text': 'The', 'analysis': []}
# {'text': ' '}
# {'text': 'Fool', 'analysis': []}
# {'text': ' '}
# {'text': 'on', 'analysis': []}
# {'text': ' '}
# {'text': 'the', 'analysis': []}
# {'text': ' '}
# {'text': 'Hill', 'analysis': []}
# {'text': '» («'}
# {'text': 'The', 'analysis': []}
# {'text': ' '}
# {'text': 'Beatles', 'analysis': []}
# {'text': '») '}
# {'text': 'на', 'analysis': [{'lex': 'на', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'исландском', 'analysis': [{'lex': 'исландский', 'gr': 'A=(пр,ед,полн,муж|пр,ед,полн,сред)'}]}
# {'text': '. '}
# {'text': 'Альбом', 'analysis': [{'lex': 'альбом', 'gr': 'S,муж,неод=(вин,ед|им,ед)'}]}
# {'text': ' '}
# {'text': 'стал', 'analysis': [{'lex': 'становиться', 'gr': 'V,нп=прош,ед,изъяв,муж,сов'}]}
# {'text': ' '}
# {'text': 'платиновым', 'analysis': [{'lex': 'платиновый', 'gr': 'A=(дат,мн,полн|твор,ед,полн,муж|твор,ед,полн,сред)'}]}
# {'text': ' '}
# {'text': 'в', 'analysis': [{'lex': 'в', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'Исландии', 'analysis': [{'lex': 'исландия', 'gr': 'S,гео,жен,неод=(пр,ед|вин,мн|дат,ед|род,ед|им,мн)'}]}
# {'text': '.'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': 'Бьорк', 'analysis': [{'lex': 'бьорк', 'qual': 'bastard', 'gr': 'S,муж,од=им,ед'}]}
# {'text': ' '}
# {'text': 'на', 'analysis': [{'lex': 'на', 'gr': 'PR='}]}
# {'text': ' '}
# ...
# {'text': ' '}
# {'text': 'благодаря', 'analysis': [{'lex': 'благодаря', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'своевременной', 'analysis': [{'lex': 'своевременный', 'gr': 'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)'}]}
# {'text': ' '}
# {'text': 'реакции', 'analysis': [{'lex': 'реакция', 'gr': 'S,жен,неод=(пр,ед|вин,мн|дат,ед|род,ед|им,мн)'}]}
# {'text': ' '}
# {'text': 'полиции', 'analysis': [{'lex': 'полиция', 'gr': 'S,жен,неод=(пр,ед|вин,мн|дат,ед|род,ед|им,мн)'}]}
# {'text': ', '}
# {'text': 'которой', 'analysis': [{'lex': 'который', 'gr': 'APRO=(пр,ед,жен|дат,ед,жен|род,ед,жен|твор,ед,жен)'}]}
# {'text': ' '}
# {'text': 'удалось', 'analysis': [{'lex': 'удаваться', 'gr': 'V,нп=прош,ед,изъяв,сред,сов'}]}
# {'text': ' '}
# {'text': 'найти', 'analysis': [{'lex': 'находить', 'gr': 'V=инф,сов,пе'}]}
# {'text': ' '}
# {'text': 'и', 'analysis': [{'lex': 'и', 'gr': 'CONJ='}]}
# {'text': ' '}
# {'text': 'обезвредить', 'analysis': [{'lex': 'обезвреживать', 'gr': 'V=инф,сов'}]}
# {'text': ' '}
# {'text': 'посылку', 'analysis': [{'lex': 'посылка', 'gr': 'S,жен,неод=вин,ед'}]}
# {'text': ' '}
# {'text': 'до', 'analysis': [{'lex': 'до', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'того', 'analysis': [{'lex': 'то', 'gr': 'SPRO,ед,сред,неод=род'}]}
# {'text': ', '}
# {'text': 'как', 'analysis': [{'lex': 'как', 'gr': 'CONJ='}]}
# {'text': ' '}
# {'text': 'она', 'analysis': [{'lex': 'она', 'gr': 'SPRO,ед,3-л,жен=им'}]}
# {'text': ' '}
# {'text': 'была', 'analysis': [{'lex': 'быть', 'gr': 'V,нп=прош,ед,изъяв,жен,несов'}]}
# {'text': ' '}
# {'text': 'доставлена', 'analysis': [{'lex': 'доставлять', 'gr': 'V,пе=прош,ед,прич,кр,жен,сов,страд'}]}
# {'text': ' '}
# {'text': 'певице', 'analysis': [{'lex': 'певица', 'gr': 'S,жен,од=(пр,ед|дат,ед)'}]}
# {'text': '. '}
# {'text': 'Именно', 'analysis': [{'lex': 'именно', 'gr': 'PART='}]}
# {'text': ' '}
# {'text': 'под', 'analysis': [{'lex': 'под', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'влиянием', 'analysis': [{'lex': 'влияние', 'gr': 'S,сред,неод=твор,ед'}]}
# {'text': ' '}
# {'text': 'этого', 'analysis': [{'lex': 'этот', 'gr': 'APRO=(вин,ед,муж,од|род,ед,муж|род,ед,сред)'}]}
# {'text': ' '}
# {'text': 'инцидента', 'analysis': [{'lex': 'инцидент', 'gr': 'S,муж,неод=род,ед'}]}
# {'text': ' '}
# {'text': 'Бьорк', 'analysis': [{'lex': 'бьорк', 'qual': 'bastard', 'gr': 'S,муж,од=им,ед'}]}
# {'text': ' '}
# {'text': 'записала', 'analysis': [{'lex': 'записывать', 'gr': 'V,пе=прош,ед,изъяв,жен,сов'}]}
# {'text': ' '}
# {'text': 'и', 'analysis': [{'lex': 'и', 'gr': 'CONJ='}]}
# {'text': ' '}
# {'text': 'выпустила', 'analysis': [{'lex': 'выпускать', 'gr': 'V=прош,ед,изъяв,жен,сов'}]}
# {'text': ' '}
# {'text': 'в', 'analysis': [{'lex': 'в', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': '1997'}
# {'text': ' '}
# {'text': 'году', 'analysis': [{'lex': 'год', 'gr': 'S,муж,неод=(дат,ед|местн,ед)'}]}
# {'text': ' '}
# {'text': 'поворотный', 'analysis': [{'lex': 'поворотный', 'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)'}]}
# {'text': ' '}
# {'text': 'в', 'analysis': [{'lex': 'в', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'её', 'analysis': [{'lex': 'ее', 'gr': 'APRO=(пр,мн|дат,мн|род,мн|твор,мн|им,мн|им,ед,жен|вин,ед,муж,од|род,ед,муж|род,ед,сред|вин,ед,сред|им,ед,сред|пр,ед,жен|дат,ед,жен|род,ед,жен|твор,ед,жен|пр,ед,муж|пр,ед,сред|дат,ед,муж|дат,ед,сред|вин,ед,жен|вин,мн,неод|вин,ед,муж,неод|им,ед,муж|твор,ед,муж|твор,ед,сред|вин,мн,од|пр,мн,сред|вин,мн,сред|дат,мн,сред|род,мн,сред|твор,мн,сред|им,мн,сред|пр,мн,муж|вин,мн,муж|вин,ед,муж|дат,мн,муж)'}]}
# {'text': ' '}
# {'text': 'творчестве', 'analysis': [{'lex': 'творчество', 'gr': 'S,сред,неод=пр,ед'}]}
# {'text': ' '}
# {'text': 'альбом', 'analysis': [{'lex': 'альбом', 'gr': 'S,муж,неод=(вин,ед|им,ед)'}]}
# {'text': ' — «'}
# {'text': 'Homogenic', 'analysis': []}
# {'text': '»['}
# {'text': '21'}
# {'text': ']['}
# {'text': '22'}
# {'text': ']'}
# {'text': '.'}
# {'text': 'ый', 'analysis': []}
# {'text': ' '}
# {'text': 'альбом', 'analysis': [{'lex': 'альбом', 'gr': 'S,муж,неод=(вин,ед|им,ед)'}]}
# {'text': ' '}
# {'text': 'записала', 'analysis': [{'lex': 'записывать', 'gr': 'V,пе=прош,ед,изъяв,жен,сов'}]}
# {'text': ' '}
# {'text': 'в', 'analysis': [{'lex': 'в', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': '11'}
# {'text': ' '}
# {'text': 'лет', 'analysis': [{'lex': 'год', 'gr': 'S,муж,неод=род,мн'}]}
# {'text': ', '}
# {'text': 'он', 'analysis': [{'lex': 'он', 'gr': 'SPRO,ед,3-л,муж=им'}]}
# {'text': ' '}
# {'text': 'приобрёл', 'analysis': [{'lex': 'приобретать', 'gr': 'V=прош,ед,изъяв,муж,сов'}]}
# {'text': ' '}
# {'text': 'большую', 'analysis': [{'lex': 'большой', 'gr': 'A=вин,ед,полн,жен'}]}
# {'text': ' '}
# {'text': 'популярность', 'analysis': [{'lex': 'популярность', 'gr': 'S,жен,неод=(вин,ед|им,ед)'}]}
# {'text': ' '}
# {'text': 'в', 'analysis': [{'lex': 'в', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'Исландии', 'analysis': [{'lex': 'исландия', 'gr': 'S,гео,жен,неод=(пр,ед|вин,мн|дат,ед|род,ед|им,мн)'}]}
# {'text': ', '}
# {'text': 'но', 'analysis': [{'lex': 'но', 'gr': 'CONJ='}]}
# {'text': ' '}
# {'text': 'мировую', 'analysis': [{'lex': 'мировой', 'gr': 'A=вин,ед,полн,жен'}]}
# {'text': ' '}
# {'text': 'известность', 'analysis': [{'lex': 'известность', 'gr': 'S,жен,неод=(вин,ед|им,ед)'}]}
# {'text': ' '}
# {'text': 'Бьорк', 'analysis': [{'lex': 'бьорк', 'qual': 'bastard', 'gr': 'S,муж,од=им,ед'}]}
# {'text': ' '}
# {'text': 'получила', 'analysis': [{'lex': 'получать', 'gr': 'V,пе=прош,ед,изъяв,жен,сов'}]}
# {'text': ' '}
# {'text': 'как', 'analysis': [{'lex': 'как', 'gr': 'CONJ='}]}
# {'text': ' '}
# {'text': 'вокалистка', 'analysis': [{'lex': 'вокалистка', 'gr': 'S,жен,од=им,ед'}]}
# {'text': ' '}
# {'text': 'альтернативной', 'analysis': [{'lex': 'альтернативный', 'gr': 'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)'}]}
# {'text': ' '}
# {'text': 'рок-группы', 'analysis': [{'lex': 'рок-группа', 'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}]}
# {'text': ' «'}
# {'text': 'The', 'analysis': []}
# {'text': ' '}
# {'text': 'Sugarcubes', 'analysis': []}
# {'text': '», '}
# {'text': 'чей', 'analysis': [{'lex': 'чей', 'gr': 'APRO=(вин,ед,муж,неод|им,ед,муж)'}]}
# {'text': ' '}
# {'text': 'сингл', 'analysis': [{'lex': 'сингл', 'gr': 'S,муж,неод=(вин,ед|им,ед)'}]}
# {'text': ' «'}
# {'text': 'Birthday', 'analysis': []}
# {'text': '» '}
# {'text': 'в', 'analysis': [{'lex': 'в', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': '1987'}
# {'text': ' '}
# {'text': 'году', 'analysis': [{'lex': 'год', 'gr': 'S,муж,неод=(дат,ед|местн,ед)'}]}
# {'text': ' '}
# {'text': 'стал', 'analysis': [{'lex': 'становиться', 'gr': 'V,нп=прош,ед,изъяв,муж,сов'}]}
# {'text': ' '}
# {'text': 'хитом', 'analysis': [{'lex': 'хит', 'gr': 'S,муж,неод=твор,ед'}]}
# {'text': ' '}
# {'text': 'в', 'analysis': [{'lex': 'в', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'Великобритании', 'analysis': [{'lex': 'великобритания', 'gr': 'S,гео,жен,неод=(пр,ед|вин,мн|дат,ед|род,ед|им,мн)'}]}
# {'text': ' '}
# {'text': 'и', 'analysis': [{'lex': 'и', 'gr': 'CONJ='}]}
# {'text': ' '}
# {'text': 'США', 'analysis': [{'lex': 'сша', 'gr': 'S,сокр,гео,мн,неод=(пр|вин|дат|род|твор|им)'}]}
# {'text': ', '}
# {'text': 'а', 'analysis': [{'lex': 'а', 'gr': 'CONJ='}]}
# {'text': ' '}
# {'text': 'также', 'analysis': [{'lex': 'также', 'gr': 'ADV='}]}
# {'text': ' '}
# {'text': 'полюбился', 'analysis': [{'lex': 'полюбиться', 'gr': 'V,сов,нп=прош,ед,изъяв,муж'}]}
# {'text': ' '}
# {'text': 'музыкальным', 'analysis': [{'lex': 'музыкальный', 'gr': 'A=(дат,мн,полн|твор,ед,полн,муж|твор,ед,полн,сред)'}]}
# {'text': ' '}
# {'text': 'критикам', 'analysis': [{'lex': 'критик', 'gr': 'S,муж,од=дат,мн'}]}
# {'text': '. '}
# {'text': 'Сольную', 'analysis': [{'lex': 'сольный', 'gr': 'A=вин,ед,полн,жен'}]}
# {'text': ' '}
# {'text': 'карьеру', 'analysis': [{'lex': 'карьера', 'gr': 'S,жен,неод=вин,ед'}]}
# {'text': ' '}
# {'text': 'Бьорк', 'analysis': [{'lex': 'бьорк', 'qual': 'bastard', 'gr': 'S,муж,од=им,ед'}]}
# {'text': ' '}
# {'text': 'начала', 'analysis': [{'lex': 'начало', 'gr': 'S,сред,неод=(вин,мн|род,ед|им,мн)'}]}
# {'text': ' '}
# {'text': 'в', 'analysis': [{'lex': 'в', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': '1993'}
# {'text': ' '}
# {'text': 'году', 'analysis': [{'lex': 'год', 'gr': 'S,муж,неод=(дат,ед|местн,ед)'}]}
# {'text': ', '}
# {'text': 'её', 'analysis': [{'lex': 'ее', 'gr': 'APRO=(пр,мн|дат,мн|род,мн|твор,мн|им,мн|им,ед,жен|вин,ед,муж,од|род,ед,муж|род,ед,сред|вин,ед,сред|им,ед,сред|пр,ед,жен|дат,ед,жен|род,ед,жен|твор,ед,жен|пр,ед,муж|пр,ед,сред|дат,ед,муж|дат,ед,сред|вин,ед,жен|вин,мн,неод|вин,ед,муж,неод|им,ед,муж|твор,ед,муж|твор,ед,сред|вин,мн,од|пр,мн,сред|вин,мн,сред|дат,мн,сред|род,мн,сред|твор,мн,сред|им,мн,сред|пр,мн,муж|вин,мн,муж|вин,ед,муж|дат,мн,муж)'}]}
# {'text': ' '}
# {'text': 'альбом', 'analysis': [{'lex': 'альбом', 'gr': 'S,муж,неод=(вин,ед|им,ед)'}]}
# {'text': ' «'}
# {'text': 'Debut', 'analysis': []}
# {'text': '» '}
# {'text': 'имел', 'analysis': [{'lex': 'иметь', 'gr': 'V,несов,пе=прош,ед,изъяв,муж'}]}
# {'text': ' '}
# {'text': 'в', 'analysis': [{'lex': 'в', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'основе', 'analysis': [{'lex': 'основа', 'gr': 'S,жен,неод=(пр,ед|дат,ед)'}]}
# {'text': ' '}
# {'text': 'электронную', 'analysis': [{'lex': 'электронный', 'gr': 'A=вин,ед,полн,жен'}]}
# {'text': ' '}
# {'text': 'танцевальную', 'analysis': [{'lex': 'танцевальный', 'gr': 'A=вин,ед,полн,жен'}]}
# {'text': ' '}
# {'text': 'музыку', 'analysis': [{'lex': 'музыка', 'gr': 'S,жен,неод=вин,ед'}]}
# {'text': ', '}
# {'text': 'хаус', 'analysis': [{'lex': 'хаус', 'gr': 'S,муж,неод=(вин,ед|им,ед)'}]}
# {'text': ', '}
# {'text': 'джаз', 'analysis': [{'lex': 'джаз', 'gr': 'S,муж,неод=(вин,ед|им,ед)'}]}
# {'text': ' '}
# {'text': 'и', 'analysis': [{'lex': 'и', 'gr': 'CONJ='}]}
# {'text': ' '}
# {'text': 'трип', 'analysis': [{'lex': 'трип', 'gr': 'S,муж,неод=(вин,ед|им,ед)'}]}
# {'text': '-'}
# {'text': 'хоп', 'analysis': [{'lex': 'хоп', 'gr': 'INTJ='}]}
# {'text': '. '}
# {'text': 'По', 'analysis': [{'lex': 'по', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'общему', 'analysis': [{'lex': 'общий', 'gr': 'A=(дат,ед,полн,муж|дат,ед,полн,сред)'}]}
# {'text': ' '}
# {'text': 'признанию', 'analysis': [{'lex': 'признание', 'gr': 'S,сред,неод=дат,ед'}]}
# {'text': ', '}
# {'text': 'это', 'analysis': [{'lex': 'это', 'gr': 'PART='}]}
# {'text': ' '}
# {'text': 'один', 'analysis': [{'lex': 'один', 'gr': 'APRO=(вин,ед,муж,неод|им,ед,муж)'}]}
# {'text': ' '}
# {'text': 'из', 'analysis': [{'lex': 'из', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'первых', 'analysis': [{'lex': 'первый', 'gr': 'ANUM=(пр,мн|род,мн|вин,мн,од)'}]}
# {'text': ' '}
# {'text': 'альбомов', 'analysis': [{'lex': 'альбом', 'gr': 'S,муж,неод=род,мн'}]}
# {'text': ' '}
# {'text': 'по', 'analysis': [{'lex': 'по', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'внедрению', 'analysis': [{'lex': 'внедрение', 'gr': 'S,сред,неод=дат,ед'}]}
# {'text': ' '}
# {'text': 'альтернативной', 'analysis': [{'lex': 'альтернативный', 'gr': 'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)'}]}
# {'text': ' '}
# {'text': 'электронной', 'analysis': [{'lex': 'электронный', 'gr': 'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)'}]}
# {'text': ' '}
# {'text': 'музыки', 'analysis': [{'lex': 'музыка', 'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}]}
# {'text': ' '}
# {'text': 'в', 'analysis': [{'lex': 'в', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'мейнстрим', 'analysis': [{'lex': 'мейнстрим', 'gr': 'S,муж,неод=(вин,ед|им,ед)'}]}
# {'text': '. '}
# {'text': 'Было', 'analysis': [{'lex': 'быть', 'gr': 'V,нп=прош,ед,изъяв,сред,несов'}]}
# {'text': ' '}
# {'text': 'продано', 'analysis': [{'lex': 'продавать', 'gr': 'V,пе=прош,ед,прич,кр,сред,сов,страд'}]}
# {'text': ' '}
# {'text': 'более', 'analysis': [{'lex': 'много', 'gr': 'ADV=срав'}]}
# {'text': ' '}
# {'text': '4'}
# {'text': ','}
# {'text': '7'}
# {'text': ' '}
# {'text': 'млн', 'analysis': []}
# {'text': ' '}
# {'text': 'копий', 'analysis': [{'lex': 'копия', 'gr': 'S,жен,неод=род,мн'}]}
# {'text': ' «'}
# {'text': 'Debut', 'analysis': []}
# {'text': '» '}
# {'text': 'по', 'analysis': [{'lex': 'по', 'gr': 'PR='}]}
# {'text': ' '}
# {'text': 'всему', 'analysis': [{'lex': 'весь', 'gr': 'APRO=(дат,ед,муж|дат,ед,сред)'}]}
# {'text': ' '}
# {'text': 'миру', 'analysis': [{'lex': 'мир', 'gr': 'S,муж,неод=дат,ед'}]}
# {'text': '.'}
# {'text': '\n'}
# ['вой', 'первбьорк', 'фамиия_муж', 'гудмундсдоттир', 'имя_жен', 'ноябрь', 'рейкьявик', 'исландия', 'исландский', 'певица', 'актриса', 'музыкант', 'композитор', 'автор', 'песня', 'лауреат', 'множество', 'премия', 'первый', 'альбом', 'записывать', 'год', 'приобретать', 'большой', 'популярность', 'исландия', 'мировой', 'известность', 'бьорк', 'получать', 'вокалистка', 'альтернативный', 'рок-группа', 'сингл', 'год', 'становиться', 'хит', 'великобритания', 'сша', 'также', 'полюбиться', 'музыкальный', 'критик', 'сольный', 'карьера', 'бьорк', 'начало', 'год', 'альбом', 'иметь', 'основа', 'электронный', 'танцевальный', 'музыка', 'хаус', 'джаз', 'трип', 'хоп', 'общий', 'признание', 'первый', 'альбом', 'внедрение', 'альтернативный', 'электронный', 'музыка', 'мейнстрим', 'быть', 'продавать', 'копия', 'мир', 'настоящий', 'момент', 'бьорк', 'разрабатывать', 'собственный', 'эклектичный', 'музыкальный', 'стиль', 'включать', 'аспект', 'электроника', 'классика', 'авангардный', 'музыка', 'альтернативный', 'танцевальный', 'музыка', 'рок', 'джаз', 'бьорк', 'написать', 'музыка', 'фильм', 'танцующий', 'темнота', 'имя_муж', 'фон', 'фамиия_муж', 'сыграть', 'главный', 'роль', 'получать', 'приз', 'хороший', 'актриса', 'каннский', 'кинофестиваль', 'также', 'принимать', 'участие', 'качество', 'композитор', 'актриса', 'фильм', 'тогдашний', 'муж', 'мэттью', 'имя_муж', 'саундтрек', 'быть', 'выпускать', 'отдельный', 'одноименный', 'альбом', 'год', 'бьорк', 'получать', 'премия', 'шведский', 'королевский', 'академия', 'музыка', 'глубоко', 'личный', 'музыка', 'слово', 'точный', 'аранжировка', 'уникальный', 'голос', 'артистка', 'сто', 'награда', 'двести', 'номинация', 'альбом', 'быть', 'первый', 'альбом', 'формат', 'мобильный', 'приложение', 'включать', 'состав', 'постоянный', 'коллекция', 'нью-йоркский', 'музей', 'современный', 'искусство', 'почти', 'год', 'проходить', 'выставка', 'мотив', 'творчество', 'бьорк', 'охватывать', 'период', 'сольный', 'карьера', 'издание', 'включать', 'бьорк', 'раздел', 'икона', 'влиятельный', 'человек', 'мир', 'называть', 'верховный', 'жрица', 'искусство', 'небольшой', 'текст', 'написать', 'имя_жен', 'фамиия_муж', 'утверждать', 'бьорк', 'учить', 'храбрость', 'быть', 'музыкальный', 'критик', 'отстаивать', 'работа', 'бьорк', 'восхвалять', 'инновационный', 'подход', 'пение', 'композиторство', 'передовой', 'использование', 'электронный', 'бит', 'прогрессивный', 'музыкальный', 'видео', 'уникальный', 'голос', 'описывать', 'важный', 'дальновидный', 'музыкант', 'поколение', 'содержание', 'скрывать', 'ранний', 'год', 'сольный', 'карьера', 'начало', 'карьера', 'настоящий', 'время', 'бьорк', 'кино', 'личный', 'жизнь', 'дискография', 'фильмография', 'камео', 'см', 'также', 'примечание', 'ссылка', 'ранний', 'год', 'править', 'править', 'код', 'музыкальный', 'карьера', 'бьорк', 'начинаться', 'быть', 'год', 'учитель', 'посылать', 'запись', 'песня', 'исполнение', 'бьорк', 'еще', 'единственный', 'радиостанция', 'исландия', 'включать', 'песня', 'эфир', 'предлагать', 'контракт', 'запись', 'альбом', 'записывать', 'дебютный', 'альбом', 'помощь', 'отчим', 'играть', 'гитара', 'альбом', 'присутствовать', 'исландский', 'детский', 'песня', 'кавер-версия', 'популярный', 'песня', 'исландский', 'альбом', 'становиться', 'платиновый', 'исландия', 'бьорк', 'гастроль', 'япония', 'состав', 'группа', 'конец', 'х', 'возраст', 'год', 'организовывать', 'панк', 'группа', 'название', 'вскоре', 'джаз', 'фьюжн', 'проект', 'год', 'бьорк', 'басистый', 'имя_муж', 'магнуссон', 'образовывать', 'группа', 'вскоре', 'переименовывать', 'проект', 'выпускать', 'год', 'альбом', 'м', 'вместе', 'имя_муж', 'имя_муж', 'фамиия_муж', 'тор', 'имя_муж', 'последний', 'быть', 'муж', 'рождаться', 'сын', 'синдри', 'год', 'организовывать', 'группа', 'плавно', 'перерасти', 'лето', 'год', 'коллектив', 'выпускать', 'несколько', 'альбом', 'альтернативный', 'музыка', 'быть', 'весьма', 'успешный', 'альтернативный', 'группа', 'число', 'великобритания', 'сша', 'интересоваться', 'фамиия_муж', 'лейбл', 'пар ...

# %%
if __name__ == '__main__' and __package__ is None:
    import_parents(level=3) # N = 3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-229-463e67735ad5> in <module>()
#       1 if __name__ == '__main__' and __package__ is None:
# ----> 2     import_parents(level=3) # N = 3
#
# NameError: name 'import_parents' is not defined

# %%
from pymystem3 import Mystem

# %%
# %tb from setuptools import setup, find_packages
setup(
    name = 'censor',
    packages = find_packages(),
)

# %%
__package__
